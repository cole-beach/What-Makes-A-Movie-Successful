# %% [markdown]
# # Part 3 - Producing a MySQL Database

# %% [markdown]
# ## Business Problem
#
# Create a database to analyze what makes a movie successful, and will provide recommendations to the stakeholder on how to make a successful movie.

# %% [markdown]
# ### Specifications - Database
#
# * Take data that has been cleaned and create a MySQL database.
#
# * Normalize the tables before adding them to the new database.
#
#     * All data from the TMDB API should be in 1 table together (even though it will not be perfectly normalized).
#
#     *Keep only imdb_id, revenue, budget, and certification columns.

# %% [markdown]
# ## Transformation Steps:
#
# * Normalize Genre:
#
#     * Convert the single string of genres from title_basics into 2 new tables.
#         1. title_genres: with columns:
#             * tconst
#             * genre_id
#
#         2. genres:
#             * genre_id
#             * genre_name
#
#
# * Discard unnecessary information:
#
#     * For the title basics table, drop the following columns:
#         * "original_title" (we will use the primary title column instead)
#         * "isAdult" ("Adult" will show up in the genres so this is redundant information).
#         * "titleType" (every row will be a movie).
#         * "genres" and other variants of genre (genre is now represented in the 2 new tables described above.
#
#     * Do not include the title_akas table in your SQL database.
#         * You have already filtered out the desired movies using this table and the remaining data is mostly nulls and not of-interest to the stakeholder.

# %% [markdown]
# ## MySQL Database Requirements

# %% [markdown]
# * Use sqlalchemy with pandas to execute your SQL queries inside your notebook.
#
#
# * Create a new database on your MySQL server and call it "movies".
#
#
#
# * Make sure to have the following tables in your "movies" database:
#
#     * title_basics
#     * title_ratings
#     * title_genres
#     * genres
#     * tmdb_data
#
#
# * Make sure to set a Primary Key for each table that isn't a joiner table (e.g. title_genres is a joiner table).
#
#
# * After creating each table, show the first 5 rows of that table using a SQL query.
#
#
# * Make sure to run the "SHOW TABLES" SQL query at the end of your notebook to show that all required tables have been created.

# %% [markdown]
# ### Deliverables
#
# Submit a link to your github respository containing the Jupyter Notebook file.

# %% [markdown]
# # Getting Started Tips

# %% [markdown]
# ## Normalizing Genres - Overview

# %% [markdown]
# * In order to normalize genres, we will need to:
#
#     * Convert the single string of genres from title basics into 2 new tables.
#
#         1. title_genres: with the columns:
#
#             * tconst
#             * genre_id
#
#         2. genres:
#             * genre_id
#             * genre_name
#
#
# * Creating these tables will be a multi-step process.
#
#
#
#         1. Getting a list of all individual genres.
#
#
#         2. Create a new title_genres table with with the movie ids duplicated, once for each genre that a movie belongs to.
#
#
#         3. Create a mapper dictionary with numeric ids for each genre.
#
#
#         4. Use the mapper dictionary to replace the string genres in title_genres with numeric genre_ids.
#
#
#         5. Convert the mapper dictionary into a final genres table with the numeric genre_id and the string genre.

# %% [markdown]
# ### 1. Getting List of Unique Genres:

# %% [markdown]
# * The genres column should be separated into separate genres.
#
#     * For example: "Comedy,Fantasy,Romance" is actually 3 genres that the movie belongs to, not one combined-genre.
#
#
# * First, you will need to get a list of all of the unique genres that appear in the column. Right now, the genre column contains a string with the genres separated by a comma.
#
#     1. We are going to convert these strings into lists of strings into a new 'genres_split' column.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os,json
import missingno as ms

plt.rcParams['figure.facecolor'] = 'white'

pd.set_option('display.max_columns',100)

# %%
FOLDER = "Data/"
sorted(os.listdir(FOLDER))
# Out:
# ['combined_tmdb_api_data.csv.gz',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'final_tmdb_data_2002.csv.gz',
#  'final_tmdb_data_2003.csv.gz',
#  'final_tmdb_data_2004.csv.gz',
#  'final_tmdb_data_2005.csv.gz',
#  'final_tmdb_data_2006.csv.gz',
#  'final_tmdb_data_2007.csv.gz',
#  'final_tmdb_data_2008.csv.gz',
#  'final_tmdb_data_2009.csv.gz',
#  'final_tmdb_data_2010.csv.gz',
#  'final_tmdb_data_2011.csv.gz',
#  'final_tmdb_data_2012.csv.gz',
#  'final_tmdb_data_2013.csv.gz',
#  'final_tmdb_data_2014.csv.gz',
#  'final_tmdb_data_2015.csv.gz',
#  'final_tmdb_data_2016.csv.gz',
#  'final_tmdb_data_2017.csv.gz',
#  'final_tmdb_data_2018.csv.gz',
#  'final_tmdb_data_2019.csv.gz',
#  'final_tmdb_data_2020.csv.gz',
#  'final_tmdb_data_2021.csv.gz',
#  'final_tmdb_data_2022.csv.gz',
#  'title_akas_cleaned.csv.gz',
#  'title_basics_cleaned.csv.gz',
#  'title_ratings_cleaned.csv.gz']

# %% [markdown]
# # Basics - Normalizing Genres

# %% [markdown]
# ## Basics

# %%
## title basics
basics = pd.read_csv(f'{FOLDER}title_basics_cleaned.csv.gz',low_memory=False)
basics.info()
basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82204 entries, 0 to 82203
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          82204 non-null  object
#  1   titleType       82204 non-null  object
#  2   primaryTitle    82204 non-null  object
#  3   originalTitle   82204 non-null  object
#  4   isAdult         82204 non-null  int64
#  5   startYear       82204 non-null  float64
#  6   runtimeMinutes  82204 non-null  int64
#  7   genres          82204 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 5.0+ MB
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0094859     movie                                         Chief Zabu
#
#                                originalTitle  isAdult  startYear  \
# 0                             Kate & Leopold        0     2001.0
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0
# 2                 The Other Side of the Wind        0     2018.0
# 3                          The Naked Monster        0     2005.0
# 4                                 Chief Zabu        0     2016.0
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4              74                  Comedy

# %% [markdown]
# ## Ratings

# %%
ratings = pd.read_csv(f"{FOLDER}/title_ratings_cleaned.csv.gz", low_memory=False)
ratings.info()
ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67422 entries, 0 to 67421
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         67422 non-null  object
#  1   averageRating  67422 non-null  float64
#  2   numVotes       67422 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.5+ MB
#       tconst  averageRating  numVotes
# 0  tt0035423            6.4     84521
# 1  tt0062336            6.4       161
# 2  tt0069049            6.7      7333
# 3  tt0088751            5.2       323
# 4  tt0094859            7.9        83

# %% [markdown]
# ## TMDB API Results

# %%
import glob
q = f"{FOLDER}final*.csv.gz"
files = glob.glob(q)
files
# Out:
# ['Data\\final_tmdb_data_2000.csv.gz',
#  'Data\\final_tmdb_data_2001.csv.gz',
#  'Data\\final_tmdb_data_2002.csv.gz',
#  'Data\\final_tmdb_data_2003.csv.gz',
#  'Data\\final_tmdb_data_2004.csv.gz',
#  'Data\\final_tmdb_data_2005.csv.gz',
#  'Data\\final_tmdb_data_2006.csv.gz',
#  'Data\\final_tmdb_data_2007.csv.gz',
#  'Data\\final_tmdb_data_2008.csv.gz',
#  'Data\\final_tmdb_data_2009.csv.gz',
#  'Data\\final_tmdb_data_2010.csv.gz',
#  'Data\\final_tmdb_data_2011.csv.gz',
#  'Data\\final_tmdb_data_2012.csv.gz',
#  'Data\\final_tmdb_data_2013.csv.gz',
#  'Data\\final_tmdb_data_2014.csv.gz',
#  'Data\\final_tmdb_data_2015.csv.gz',
#  'Data\\final_tmdb_data_2016.csv.gz',
#  'Data\\final_tmdb_data_2017.csv.gz',
#  'Data\\final_tmdb_data_2018.csv.gz',
#  'Data\\final_tmdb_data_2019.csv.gz',
#  'Data\\final_tmdb_data_2020.csv.gz',
#  'Data\\final_tmdb_data_2021.csv.gz',
#  'Data\\final_tmdb_data_2022.csv.gz']

# %%
df = pd.concat([pd.read_csv(f) for f in files])
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62384 entries, 0 to 1679
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  62384 non-null  bool
#  1   backdrop_path          39108 non-null  object
#  2   belongs_to_collection  3980 non-null   object
#  3   budget                 62384 non-null  int64
#  4   genres                 62384 non-null  object
#  5   homepage               15351 non-null  object
#  6   id                     62384 non-null  int64
#  7   imdb_id                62384 non-null  object
#  8   original_language      62384 non-null  object
#  9   original_title         62384 non-null  object
#  10  overview               61003 non-null  object
#  11  popularity             62384 non-null  float64
#  12  poster_path            56816 non-null  object
#  13  production_companies   62384 non-null  object
#  14  production_countries   62384 non-null  object
#  15  release_date           61262 non-null  object
#  16  revenue                62384 non-null  int64
#  17  runtime                62384 non-null  int64
#  18  spoken_languages       62384 non-null  object
#  19  status                 62384 non-null  object
#  20  tagline                23263 non-null  object
#  21  title                  62384 non-null  object
#  22  video                  62384 non-null  bool
#  23  vote_average           62384 non-null  float64
#  24  vote_count             62384 non-null  int64
#  25  certification          15140 non-null  object
# dtypes: bool(2), float64(2), int64(5), object(17)
# memory usage: 12.0+ MB
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN  10000000
# 1  False                               NaN                   NaN         0
# 2  False                               NaN                   NaN         0
# 3  False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN    150000
# 4  False                               NaN                   NaN         0
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1           [{'id': 878, 'name': 'Science Fiction'}]
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4                      [{'id': 18, 'name': 'Drama'}]
#
#                                homepage      id    imdb_id original_language  \
# 0                                   NaN   62127  tt0113026                en
# 1                                   NaN  110977  tt0113092                en
# 2                                   NaN  442869  tt0116391                hi
# 3  http://www.wkw-inthemoodforlove.com/     843  tt0118694                cn
# 4                                   NaN   49511  tt0118852                en
#
#     original_title                                           overview  \
# 0  The Fantasticks  Two rural teens sing and dance their way throu...
# 1    For the Cause  Earth is in a state of constant war and two co...
# 2             Gang  After falling prey to underworld, four friends...
# 3             花樣年華  Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...
# 4   Chinese Coffee  When Harry Levine, an aging, unsuccessful Gree...
#
#    popularity                       poster_path  \
# 0       2.289  /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1       3.133  /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2       1.091  /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 3      22.892  /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4       3.913  /nZGWnSuf1FIuzyEuMRZHHZWViAp.jpg
#
#                                 production_companies  \
# 0  [{'id': 60, 'logo_path': '/2eqFolQI0NLL7ExZts5...
# 1  [{'id': 925, 'logo_path': '/dIb9hjXNOkgxu4kBWd...
# 2                                                 []
# 3  [{'id': 539, 'logo_path': None, 'name': 'Block...
# 4  [{'id': 1596, 'logo_path': None, 'name': 'Shoo...
#
#                                 production_countries release_date   revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22         0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15         0
# 2            [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14         0
# 3        [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29  12854953
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02         0
#
#    runtime                                   spoken_languages    status  \
# 0       86  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1      100  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2      152  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3       99  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4       99  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                 title  \
# 0      Try to remember the first time magic happened       The Fantasticks
# 1       The ultimate showdown on a forbidden planet.         For the Cause
# 2                                                NaN                  Gang
# 3  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
# 4  There's a fine line between friendship and bet...        Chinese Coffee
#
#    video  vote_average  vote_count certification
# 0  False         5.500          22           NaN
# 1  False         5.100           8           NaN
# 2  False         0.000           0           NaN
# 3  False         8.103        1948            PG
# 4  False         6.900          46             R

# %%
# Dropping Placeholder rows with id=0
df = df.loc[df['imdb_id']!='0']

# %% [markdown]
# # Transform

# %% [markdown]
# ## Basics

# %% [markdown]
# ***
# * Normalize and Separate Genre.
#
# * `origninal_title` (Use the primary title column instead).
#
# * `isAdult` ("Adult" will show up in the genres so this is redundant information).
#
# * `titleType` (every row will be a movie).
#
# * `genres` and other variants of genre (genre is now represented in the 2 new tables described above).
#
# ***

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82204 entries, 0 to 82203
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          82204 non-null  object
#  1   titleType       82204 non-null  object
#  2   primaryTitle    82204 non-null  object
#  3   originalTitle   82204 non-null  object
#  4   isAdult         82204 non-null  int64
#  5   startYear       82204 non-null  float64
#  6   runtimeMinutes  82204 non-null  int64
#  7   genres          82204 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 5.0+ MB

# %%
# columns to drop
columns_dropped = ['originalTitle', 'isAdult', 'titleType']
basics = basics.drop(columns=columns_dropped)
basics
# Out:
#           tconst                                       primaryTitle  \
# 0      tt0035423                                     Kate & Leopold
# 1      tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049                         The Other Side of the Wind
# 3      tt0088751                                  The Naked Monster
# 4      tt0094859                                         Chief Zabu
# ...          ...                                                ...
# 82199  tt9914942                             Life Without Sara Amat
# 82200  tt9915872                               The Last White Witch
# 82201  tt9916170                                      The Rehearsal
# 82202  tt9916190                                          Safeguard
# 82203  tt9916362                                              Coven
#
#        startYear  runtimeMinutes                     genres
# 0         2001.0             118     Comedy,Fantasy,Romance
# 1         2020.0              70                      Drama
# 2         2018.0             122                      Drama
# 3         2005.0             100       Comedy,Horror,Sci-Fi
# 4         2016.0              74                     Comedy
# ...          ...             ...                        ...
# 82199     2019.0              74                      Drama
# 82200     2019.0              97       Comedy,Drama,Fantasy
# 82201     2019.0              51                      Drama
# 82202     2020.0              95  Action,Adventure,Thriller
# 82203     2020.0              92              Drama,History
#
# [82204 rows x 5 columns]

# %% [markdown]
# ### Normalizing Genres

# %%
# Fill in Missing genres
# creat a new column with single-string genres as a list of strings
basics['genres_split'] = basics['genres'].str.split(',')
basics
# Out:
#           tconst                                       primaryTitle  \
# 0      tt0035423                                     Kate & Leopold
# 1      tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049                         The Other Side of the Wind
# 3      tt0088751                                  The Naked Monster
# 4      tt0094859                                         Chief Zabu
# ...          ...                                                ...
# 82199  tt9914942                             Life Without Sara Amat
# 82200  tt9915872                               The Last White Witch
# 82201  tt9916170                                      The Rehearsal
# 82202  tt9916190                                          Safeguard
# 82203  tt9916362                                              Coven
#
#        startYear  runtimeMinutes                     genres  \
# 0         2001.0             118     Comedy,Fantasy,Romance
# 1         2020.0              70                      Drama
# 2         2018.0             122                      Drama
# 3         2005.0             100       Comedy,Horror,Sci-Fi
# 4         2016.0              74                     Comedy
# ...          ...             ...                        ...
# 82199     2019.0              74                      Drama
# 82200     2019.0              97       Comedy,Drama,Fantasy
# 82201     2019.0              51                      Drama
# 82202     2020.0              95  Action,Adventure,Thriller
# 82203     2020.0              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                           [Comedy]
# ...                              ...
# 82199                        [Drama]
# 82200       [Comedy, Drama, Fantasy]
# 82201                        [Drama]
# 82202  [Action, Adventure, Thriller]
# 82203               [Drama, History]
#
# [82204 rows x 6 columns]

# %%
# Explode dataframe to make each genre into a separate rows
exploded_data = basics.explode('genres_split')
exploded_data
# Out:
#           tconst                                       primaryTitle  \
# 0      tt0035423                                     Kate & Leopold
# 0      tt0035423                                     Kate & Leopold
# 0      tt0035423                                     Kate & Leopold
# 1      tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049                         The Other Side of the Wind
# ...          ...                                                ...
# 82202  tt9916190                                          Safeguard
# 82202  tt9916190                                          Safeguard
# 82202  tt9916190                                          Safeguard
# 82203  tt9916362                                              Coven
# 82203  tt9916362                                              Coven
#
#        startYear  runtimeMinutes                     genres genres_split
# 0         2001.0             118     Comedy,Fantasy,Romance       Comedy
# 0         2001.0             118     Comedy,Fantasy,Romance      Fantasy
# 0         2001.0             118     Comedy,Fantasy,Romance      Romance
# 1         2020.0              70                      Drama        Drama
# 2         2018.0             122                      Drama        Drama
# ...          ...             ...                        ...          ...
# 82202     2020.0              95  Action,Adventure,Thriller       Action
# 82202     2020.0              95  Action,Adventure,Thriller    Adventure
# 82202     2020.0              95  Action,Adventure,Thriller     Thriller
# 82203     2020.0              92              Drama,History        Drama
# 82203     2020.0              92              Drama,History      History
#
# [153592 rows x 6 columns]

# %%
# saving tconst and genres_split as a new df
title_genres = exploded_data[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
# Replacing text genres with integer IDs
unique_genres = sorted(title_genres['genres_split'].unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
# Create dictionary with list of unique genres as the key and the new iteger id as values
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
## Use .map or .replace with our genre_id_map dictionary
title_genres['Genre_ID'] = title_genres['genres_split'].replace(genre_id_map)

## Drop the original genre column
title_genres.drop(columns=['genres_split'],inplace=True)
title_genres
# Out:
#           tconst  Genre_ID
# 0      tt0035423         5
# 0      tt0035423         9
# 0      tt0035423        18
# 1      tt0062336         7
# 2      tt0069049         7
# ...          ...       ...
# 82202  tt9916190         0
# 82202  tt9916190         2
# 82202  tt9916190        23
# 82203  tt9916362         7
# 82203  tt9916362        11
#
# [153592 rows x 2 columns]

# %% [markdown]
# # Creating Tables

# %% [markdown]
# ## genres table

# %%
## Manaully make dataframe with named cols from the .keyd and .values
genre_lookup = pd.DataFrame({'Genre_Name': genre_id_map.keys(),
                             'Genre_ID':genre_id_map.values()})
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
## Dropping original genre columns 
basics = basics.drop(columns=['genres','genres_split'])
basics
# Out:
#           tconst                                       primaryTitle  \
# 0      tt0035423                                     Kate & Leopold
# 1      tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049                         The Other Side of the Wind
# 3      tt0088751                                  The Naked Monster
# 4      tt0094859                                         Chief Zabu
# ...          ...                                                ...
# 82199  tt9914942                             Life Without Sara Amat
# 82200  tt9915872                               The Last White Witch
# 82201  tt9916170                                      The Rehearsal
# 82202  tt9916190                                          Safeguard
# 82203  tt9916362                                              Coven
#
#        startYear  runtimeMinutes
# 0         2001.0             118
# 1         2020.0              70
# 2         2018.0             122
# 3         2005.0             100
# 4         2016.0              74
# ...          ...             ...
# 82199     2019.0              74
# 82200     2019.0              97
# 82201     2019.0              51
# 82202     2020.0              95
# 82203     2020.0              92
#
# [82204 rows x 4 columns]

# %% [markdown]
# # Connecting to MySQL

# %%
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
from sqlalchemy.types import *
# engine = create_engine(connection_str)

# %%
## Getting mysql server password
import json
with open(r"C:\Users\nbeac\.secret\tmdb_api.json") as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
connect_str = connection_str = "mysql+pymysql://root:iamroot@localhost/movies"

# %%
## Check if database exists, if not, create it
if database_exists(connect_str) == False:
    print("Creating the database.")
    create_database(connect_str)
else:
    print('The database already exists.')
# Out:
# The database already exists.

# %%
## create engine
engine = create_engine(connect_str)

# %%
## Test your connection by checking for any tables that exist (there should be none at this point)
q = """SHOW TABLES;"""
tables = pd.read_sql(q, engine)
tables
# Out:
#   Tables_in_movies
# 0           genres
# 1     title_basics
# 2     title_genres
# 3    title_ratings
# 4    tmdb_data_aab
# 5    tmdb_data_mvp

# %% [markdown]
# ## Saving `title_basics`

# %%
## saving text length
key_len = basics['tconst'].map(len).max()
title_len = basics['primaryTitle'].map(len).max()
key_len, title_len
# Out:
# (10, 242)

# %%
basics_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'runtimeMinutes':Integer()
    }
basics_schema
# Out:
# {'tconst': String(length=11),
#  'primaryTitle': Text(length=243),
#  'startYear': Float(),
#  'runtimeMinutes': Integer()}

# %%
basics
# Out:
#           tconst                                       primaryTitle  \
# 0      tt0035423                                     Kate & Leopold
# 1      tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049                         The Other Side of the Wind
# 3      tt0088751                                  The Naked Monster
# 4      tt0094859                                         Chief Zabu
# ...          ...                                                ...
# 82199  tt9914942                             Life Without Sara Amat
# 82200  tt9915872                               The Last White Witch
# 82201  tt9916170                                      The Rehearsal
# 82202  tt9916190                                          Safeguard
# 82203  tt9916362                                              Coven
#
#        startYear  runtimeMinutes
# 0         2001.0             118
# 1         2020.0              70
# 2         2018.0             122
# 3         2005.0             100
# 4         2016.0              74
# ...          ...             ...
# 82199     2019.0              74
# 82200     2019.0              97
# 82201     2019.0              51
# 82202     2020.0              95
# 82203     2020.0              92
#
# [82204 rows x 4 columns]

# %%
## Saving basics as table with schema,
basics.to_sql('title_basics',engine,dtype=basics_schema,if_exists='replace',index=False)

## setting title basics as the primary key
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
## query first rows 
q = """SELECT * FROM title_basics LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0088751                                  The Naked Monster     2005.0
# 4  tt0094859                                         Chief Zabu     2016.0
#
#    runtimeMinutes
# 0             118
# 1              70
# 2             122
# 3             100
# 4              74

# %% [markdown]
# ## Saving Genre Tables

# %%
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
## Primary key is Genre_ID
genre_lookup.to_sql('genres',engine,index=False, if_exists='replace')

engine.execute('ALTER TABLE genres ADD PRIMARY KEY (`Genre_ID`);')

# %%
q = """SELECT * FROM genres LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# ### Saving `title_genres` table

# %%
## NO PRIMARY KEY - DUPLCIATE VALUES
title_genres.to_sql('title_genres',engine,index=False,
                    if_exists='replace' )

# engine.execute('ALTER TABLE title_genres ADD PRIMARY KEY (`tconst`);')
# Out:
# 153592

# %%
q = """SELECT * FROM title_genres LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#       tconst  Genre_ID
# 0  tt0035423         5
# 1  tt0035423         9
# 2  tt0035423        18
# 3  tt0062336         7
# 4  tt0069049         7

# %% [markdown]
# ### Saving `title_ratings`

# %%
ratings_schema = {'tconst':String(key_len+1), 
                 'averageRating':Float(),
                 'numVotes':Integer()}#get_schema(ratings)
ratings_schema
# Out:
# {'tconst': String(length=11), 'averageRating': Float(), 'numVotes': Integer()}

# %%
ratings.to_sql('title_ratings',engine,if_exists='replace',index=False,
              dtype=ratings_schema)
engine.execute("ALTER TABLE title_ratings ADD PRIMARY KEY (`tconst`)")

# %%
q = """SELECT * FROM title_ratings LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0035423            6.4     84521
# 1  tt0062336            6.4       161
# 2  tt0069049            6.7      7333
# 3  tt0088751            5.2       323
# 4  tt0094859            7.9        83

# %% [markdown]
# ### Saving `TMDB API` Data

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62384 entries, 0 to 1679
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  62384 non-null  bool
#  1   backdrop_path          39108 non-null  object
#  2   belongs_to_collection  3980 non-null   object
#  3   budget                 62384 non-null  int64
#  4   genres                 62384 non-null  object
#  5   homepage               15351 non-null  object
#  6   id                     62384 non-null  int64
#  7   imdb_id                62384 non-null  object
#  8   original_language      62384 non-null  object
#  9   original_title         62384 non-null  object
#  10  overview               61003 non-null  object
#  11  popularity             62384 non-null  float64
#  12  poster_path            56816 non-null  object
#  13  production_companies   62384 non-null  object
#  14  production_countries   62384 non-null  object
#  15  release_date           61262 non-null  object
#  16  revenue                62384 non-null  int64
#  17  runtime                62384 non-null  int64
#  18  spoken_languages       62384 non-null  object
#  19  status                 62384 non-null  object
#  20  tagline                23263 non-null  object
#  21  title                  62384 non-null  object
#  22  video                  62384 non-null  bool
#  23  vote_average           62384 non-null  float64
#  24  vote_count             62384 non-null  int64
#  25  certification          15140 non-null  object
# dtypes: bool(2), float64(2), int64(5), object(17)
# memory usage: 12.0+ MB
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN  10000000
# 1  False                               NaN                   NaN         0
# 2  False                               NaN                   NaN         0
# 3  False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN    150000
# 4  False                               NaN                   NaN         0
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1           [{'id': 878, 'name': 'Science Fiction'}]
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4                      [{'id': 18, 'name': 'Drama'}]
#
#                                homepage      id    imdb_id original_language  \
# 0                                   NaN   62127  tt0113026                en
# 1                                   NaN  110977  tt0113092                en
# 2                                   NaN  442869  tt0116391                hi
# 3  http://www.wkw-inthemoodforlove.com/     843  tt0118694                cn
# 4                                   NaN   49511  tt0118852                en
#
#     original_title                                           overview  \
# 0  The Fantasticks  Two rural teens sing and dance their way throu...
# 1    For the Cause  Earth is in a state of constant war and two co...
# 2             Gang  After falling prey to underworld, four friends...
# 3             花樣年華  Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...
# 4   Chinese Coffee  When Harry Levine, an aging, unsuccessful Gree...
#
#    popularity                       poster_path  \
# 0       2.289  /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1       3.133  /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2       1.091  /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 3      22.892  /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4       3.913  /nZGWnSuf1FIuzyEuMRZHHZWViAp.jpg
#
#                                 production_companies  \
# 0  [{'id': 60, 'logo_path': '/2eqFolQI0NLL7ExZts5...
# 1  [{'id': 925, 'logo_path': '/dIb9hjXNOkgxu4kBWd...
# 2                                                 []
# 3  [{'id': 539, 'logo_path': None, 'name': 'Block...
# 4  [{'id': 1596, 'logo_path': None, 'name': 'Shoo...
#
#                                 production_countries release_date   revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22         0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15         0
# 2            [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14         0
# 3        [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29  12854953
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02         0
#
#    runtime                                   spoken_languages    status  \
# 0       86  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1      100  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2      152  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3       99  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4       99  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                 title  \
# 0      Try to remember the first time magic happened       The Fantasticks
# 1       The ultimate showdown on a forbidden planet.         For the Cause
# 2                                                NaN                  Gang
# 3  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
# 4  There's a fine line between friendship and bet...        Chinese Coffee
#
#    video  vote_average  vote_count certification
# 0  False         5.500          22           NaN
# 1  False         5.100           8           NaN
# 2  False         0.000           0           NaN
# 3  False         8.103        1948            PG
# 4  False         6.900          46             R

# %%
## Keeping some columns
cols_to_keep = ['imdb_id','budget','revenue','certification',
                'original_language']
mvp = df[cols_to_keep]
mvp
# Out:
#         imdb_id    budget   revenue certification original_language
# 0     tt0113026  10000000         0           NaN                en
# 1     tt0113092         0         0           NaN                en
# 2     tt0116391         0         0           NaN                hi
# 3     tt0118694    150000  12854953            PG                cn
# 4     tt0118852         0         0             R                en
# ...         ...       ...       ...           ...               ...
# 1675  tt9851854         0         0           NaN                te
# 1676  tt9854058         0         0           NaN                en
# 1677  tt9893158         0         0           NaN                en
# 1678  tt9893160         0         0           NaN                en
# 1679  tt9904648         0         0           NaN                en
#
# [62384 rows x 5 columns]

# %%
mvp.isna().sum()
# Out:
# imdb_id                  0
# budget                   0
# revenue                  0
# certification        47244
# original_language        0
# dtype: int64

# %%
mvp
# Out:
#         imdb_id    budget   revenue certification original_language
# 0     tt0113026  10000000         0           NaN                en
# 1     tt0113092         0         0           NaN                en
# 2     tt0116391         0         0           NaN                hi
# 3     tt0118694    150000  12854953            PG                cn
# 4     tt0118852         0         0             R                en
# ...         ...       ...       ...           ...               ...
# 1675  tt9851854         0         0           NaN                te
# 1676  tt9854058         0         0           NaN                en
# 1677  tt9893158         0         0           NaN                en
# 1678  tt9893160         0         0           NaN                en
# 1679  tt9904648         0         0           NaN                en
#
# [62384 rows x 5 columns]

# %%
## saving text length
key_len = mvp['imdb_id'].map(len).max()
cert_len = mvp['certification'].fillna('').map(len).max()
lang_len = mvp['original_language'].map(len).max()

key_len, cert_len,lang_len
# Out:
# (10, 31, 2)

# %%
## saving schema
api_data_schema = {'imdb_id':String(key_len+1), 
                 'budget':Float(),
                   'revenue':Float(),
                 'certification':Text(cert_len+1),
                  'original_language':Text(lang_len+1)}
api_data_schema
# Out:
# {'imdb_id': String(length=11),
#  'budget': Float(),
#  'revenue': Float(),
#  'certification': Text(length=32),
#  'original_language': Text(length=3)}

# %%
## Primary key is Genre_ID
mvp.to_sql('tmdb_data_mvp',engine, index=False,dtype=api_data_schema, if_exists='replace')

engine.execute('ALTER TABLE tmdb_data_mvp ADD PRIMARY KEY (`imdb_id`);')

# %%
q = """SELECT * FROM tmdb_data_mvp LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#      imdb_id      budget     revenue certification original_language
# 0  tt0035423  48000000.0  76019000.0         PG-13                en
# 1  tt0062336         0.0         0.0          None                es
# 2  tt0069049  12000000.0         0.0             R                en
# 3  tt0088751    350000.0         0.0          None                en
# 4  tt0094859       187.0         0.0          None                en

# %%
df.head()
# Out:
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN  10000000
# 1  False                               NaN                   NaN         0
# 2  False                               NaN                   NaN         0
# 3  False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN    150000
# 4  False                               NaN                   NaN         0
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1           [{'id': 878, 'name': 'Science Fiction'}]
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4                      [{'id': 18, 'name': 'Drama'}]
#
#                                homepage      id    imdb_id original_language  \
# 0                                   NaN   62127  tt0113026                en
# 1                                   NaN  110977  tt0113092                en
# 2                                   NaN  442869  tt0116391                hi
# 3  http://www.wkw-inthemoodforlove.com/     843  tt0118694                cn
# 4                                   NaN   49511  tt0118852                en
#
#     original_title                                           overview  \
# 0  The Fantasticks  Two rural teens sing and dance their way throu...
# 1    For the Cause  Earth is in a state of constant war and two co...
# 2             Gang  After falling prey to underworld, four friends...
# 3             花樣年華  Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...
# 4   Chinese Coffee  When Harry Levine, an aging, unsuccessful Gree...
#
#    popularity                       poster_path  \
# 0       2.289  /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1       3.133  /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2       1.091  /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 3      22.892  /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4       3.913  /nZGWnSuf1FIuzyEuMRZHHZWViAp.jpg
#
#                                 production_companies  \
# 0  [{'id': 60, 'logo_path': '/2eqFolQI0NLL7ExZts5...
# 1  [{'id': 925, 'logo_path': '/dIb9hjXNOkgxu4kBWd...
# 2                                                 []
# 3  [{'id': 539, 'logo_path': None, 'name': 'Block...
# 4  [{'id': 1596, 'logo_path': None, 'name': 'Shoo...
#
#                                 production_countries release_date   revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22         0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15         0
# 2            [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14         0
# 3        [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29  12854953
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02         0
#
#    runtime                                   spoken_languages    status  \
# 0       86  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1      100  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2      152  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3       99  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4       99  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                 title  \
# 0      Try to remember the first time magic happened       The Fantasticks
# 1       The ultimate showdown on a forbidden planet.         For the Cause
# 2                                                NaN                  Gang
# 3  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
# 4  There's a fine line between friendship and bet...        Chinese Coffee
#
#    video  vote_average  vote_count certification
# 0  False         5.500          22           NaN
# 1  False         5.100           8           NaN
# 2  False         0.000           0           NaN
# 3  False         8.103        1948            PG
# 4  False         6.900          46             R

# %%
# # saving AAB version
# ## Primary key is Genre_ID
# df.to_sql('tmdb_data_aab',engine, index=False,dtype=api_data_schema, if_exists='replace')
# engine.execute('ALTER TABLE tmdb_data_aab ADD PRIMARY KEY (`imdb_id`);')

# %%
def get_schema(table,debug=False):
    ## save pandas dtypes in list, make empty dict
    dtypes = table.dtypes
    schema = {}
    
    # for each column
    for col in dtypes.index:
        ## print info if in debug mode
        if debug:
            print(f"{col} = {dtypes.loc[col]}")

        ## if its a string column (object)
        if dtypes.loc[col]=='object':
            
            ## Fill null values and make sure whole column is str
            data = table[col].fillna('').astype(str)
            
            ## get len first
            len_str = data.map(len).max()
            
            ## if the string is shorter than 21845 use String
            # (forget how i knew it was max size)
            if len_str < 21845:
                schema[col] = String( len_str + 1)
                
            ## If longer use Text
            else:
                schema[col] = Text(len_str+1)
        
        # if float make Float
        elif dtypes.loc[col] == 'float':
            schema[col] = Float()

        ## if int make Integer
        elif dtypes.loc[col] == 'int':
            schema[col] = Integer()
            
        ## if bool make Boolean
        elif dtypes.loc[col] == 'bool':
            schema[col] = Boolean()
            
    return schema

# %%
len(df)
# Out:
# 62384

# %%
# identifying incomaptible rows
bad_titles = (df['original_title']!=df['title']) &\
                (df['original_language']!='en') &\
               ~df['spoken_languages'].str.contains('english',case=False)
df[bad_titles]
# Out:
#       adult                     backdrop_path belongs_to_collection  budget  \
# 513   False  /v0yLHXchzHdAESEBx9ix3tbyV5r.jpg                   NaN       0
# 585   False                               NaN                   NaN       0
# 593   False                               NaN                   NaN       0
# 754   False                               NaN                   NaN       0
# 843   False                               NaN                   NaN       0
# ...     ...                               ...                   ...     ...
# 1331  False  /4f0bOEFJaUm9N3acffJk5J1Fmey.jpg                   NaN       0
# 1349  False                               NaN                   NaN       0
# 1392  False  /m7GkAuvm5jaRvdLeue1m0lEvD8p.jpg                   NaN       0
# 1421  False                               NaN                   NaN       0
# 1643  False                               NaN                   NaN       0
#
#                                                  genres homepage       id  \
# 513                       [{'id': 18, 'name': 'Drama'}]      NaN    73525
# 585                                                  []      NaN   550283
# 593                                                  []      NaN   572393
# 754                                                  []      NaN   713555
# 843                                                  []      NaN   345083
# ...                                                 ...      ...      ...
# 1331                      [{'id': 18, 'name': 'Drama'}]      NaN   890591
# 1349                      [{'id': 18, 'name': 'Drama'}]      NaN   993249
# 1392                      [{'id': 18, 'name': 'Drama'}]      NaN  1005299
# 1421  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...      NaN   269579
# 1643                  [{'id': 16, 'name': 'Animation'}]      NaN   970589
#
#          imdb_id original_language  \
# 513    tt0216990                es
# 585    tt0222023                es
# 593    tt0222989                fr
# 754    tt0243171                fa
# 843    tt0251353                it
# ...          ...               ...
# 1331  tt20517646                it
# 1349  tt20877264                ka
# 1392  tt21378744                fa
# 1421   tt2818640                es
# 1643   tt9223884                es
#
#                                          original_title  \
# 513                                    Sin dejar huella
# 585   Hubo un tiempo en que los sueños dieron paso a...
# 593                         Chittagong: Dernière escale
# 754                                              Charkh
# 843                             Delitto in Prima Serata
# ...                                                 ...
# 1331                        Prossimo Tuo (Hotel Milano)
# 1349                                       Chemi otakhi
# 1392                                      جنگ جهانی سوم
# 1421                   Un cuento de circo & a love song
# 1643                                      La otra forma
#
#                                                overview  popularity  \
# 513   A woman steals from her drug-dealer boyfriend ...       1.606
# 585   Bruno, a young prostitute on the streets of Me...       0.600
# 593                                                 NaN       0.600
# 754   When he loses his football playing with a coup...       0.600
# 843   Someone is murdered in a European modeling age...       0.600
# ...                                                 ...         ...
# 1331  Riki and Luca are two young men in search of t...       0.600
# 1349  Tina, a young woman who has lost her way in li...       0.600
# 1392                                                NaN       4.034
# 1421  A boy who grew up at the circus decides to lea...       1.105
# 1643  Peter Press has been living with a press for 2...       0.628
#
#                            poster_path  \
# 513   /hfoci8y0lOEKsykZDrV47vjNOKt.jpg
# 585   /fwyml5vli57318zgS2hqH6jQMeY.jpg
# 593   /k2bi20nfkZYmWJZXNk0NrENhdcH.jpg
# 754   /yWRRJlIbVUNYcXpNhUc7u6nFTos.jpg
# 843   /vU1AvCa8klwIsorISI5lkd6kYRc.jpg
# ...                                ...
# 1331  /7povyIL3MNYdm8DMNICDzOxdTWw.jpg
# 1349  /hugiYuqHeSwB7CM1st1VWj4h7vH.jpg
# 1392  /xG0nLMvAlDfLhXe6LZBu0LVU38T.jpg
# 1421  /xXhbxTbNenb4G91b3mvTVMfeq4O.jpg
# 1643  /baRbB4Sx2KIomYDWQZbgGmNrh5E.jpg
#
#                                    production_companies  \
# 513   [{'id': 357, 'logo_path': None, 'name': 'Vía D...
# 585                                                  []
# 593                                                  []
# 754                                                  []
# 843                                                  []
# ...                                                 ...
# 1331  [{'id': 127343, 'logo_path': None, 'name': 'Ze...
# 1349                                                 []
# 1392                                                 []
# 1421                                                 []
# 1643  [{'id': 174659, 'logo_path': None, 'name': 'HI...
#
#                                    production_countries release_date  revenue  \
# 513   [{'iso_3166_1': 'MX', 'name': 'Mexico'}, {'iso...   2001-03-23        0
# 585            [{'iso_3166_1': 'MX', 'name': 'Mexico'}]   2000-06-16        0
# 593                                                  []   2001-12-05        0
# 754                                                  []   2000-04-09        0
# 843                                                  []   2000-01-01        0
# ...                                                 ...          ...      ...
# 1331            [{'iso_3166_1': 'IT', 'name': 'Italy'}]          NaN        0
# 1349                                                 []   2022-07-04        0
# 1392                                                 []   2022-08-31        0
# 1421           [{'iso_3166_1': 'MX', 'name': 'Mexico'}]   2022-12-31        0
# 1643                                                 []   2022-06-11        0
#
#       runtime spoken_languages           status tagline  \
# 513       109               []         Released     NaN
# 585        50               []         Released     NaN
# 593         0               []         Released     NaN
# 754        70               []         Released     NaN
# 843        85               []         Released     NaN
# ...       ...              ...              ...     ...
# 1331        0               []  Post Production     NaN
# 1349      107               []         Released     NaN
# 1392      117               []    In Production     NaN
# 1421      114               []    In Production     NaN
# 1643       99               []         Released     NaN
#
#                               title  video  vote_average  vote_count  \
# 513                 Without a Trace  False           6.5          10
# 585           Long Sleepless Nights  False           5.0           2
# 593   Chittagong: The Last Stopover  False           0.0           0
# 754                        The Cart  False           0.0           0
# 843                Primetime Murder  False           0.0           0
# ...                             ...    ...           ...         ...
# 1331                   The Neighbor  False           0.0           0
# 1349                 Room Of My Own  False           0.0           0
# 1392                  World War III  False           0.0           0
# 1421    A circus tale & a love song  False           0.0           0
# 1643                The Other Shape  False           2.0           1
#
#      certification
# 513            NaN
# 585            NaN
# 593            NaN
# 754            NaN
# 843            NaN
# ...            ...
# 1331           NaN
# 1349           NaN
# 1392           NaN
# 1421           NaN
# 1643           NaN
#
# [377 rows x 26 columns]

# %%
df = df[~bad_titles]
df
# Out:
#       adult                     backdrop_path belongs_to_collection    budget  \
# 0     False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN  10000000
# 1     False                               NaN                   NaN         0
# 2     False                               NaN                   NaN         0
# 3     False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN    150000
# 4     False                               NaN                   NaN         0
# ...     ...                               ...                   ...       ...
# 1675  False  /8tyq1kXM3YQmu3obW6LxWm5TVRO.jpg                   NaN         0
# 1676  False                               NaN                   NaN         0
# 1677  False                               NaN                   NaN         0
# 1678  False  /jX5XGqJUTzvpta2RjcX6pMZqxk5.jpg                   NaN         0
# 1679  False  /ibWj2ARVrAabIWDq5vSXoJRZfVV.jpg                   NaN         0
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1              [{'id': 878, 'name': 'Science Fiction'}]
# 2     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4                         [{'id': 18, 'name': 'Drama'}]
# ...                                                 ...
# 1675  [{'id': 28, 'name': 'Action'}, {'id': 36, 'nam...
# 1676                      [{'id': 80, 'name': 'Crime'}]
# 1677  [{'id': 80, 'name': 'Crime'}, {'id': 10749, 'n...
# 1678  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 1679  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                                   homepage      id    imdb_id  \
# 0                                      NaN   62127  tt0113026
# 1                                      NaN  110977  tt0113092
# 2                                      NaN  442869  tt0116391
# 3     http://www.wkw-inthemoodforlove.com/     843  tt0118694
# 4                                      NaN   49511  tt0118852
# ...                                    ...     ...        ...
# 1675                                   NaN  605153  tt9851854
# 1676                                   NaN  969840  tt9854058
# 1677                                   NaN  796955  tt9893158
# 1678                                   NaN  606303  tt9893160
# 1679            https://contrastmovie.com/  933557  tt9904648
#
#      original_language   original_title  \
# 0                   en  The Fantasticks
# 1                   en    For the Cause
# 2                   hi             Gang
# 3                   cn             花樣年華
# 4                   en   Chinese Coffee
# ...                ...              ...
# 1675                te            మేజర్
# 1676                en          Shadows
# 1677                en         Clowning
# 1678                en       No Way Out
# 1679                en     The Contrast
#
#                                                overview  popularity  \
# 0     Two rural teens sing and dance their way throu...       2.289
# 1     Earth is in a state of constant war and two co...       3.133
# 2     After falling prey to underworld, four friends...       1.091
# 3     Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...      22.892
# 4     When Harry Levine, an aging, unsuccessful Gree...       3.913
# ...                                                 ...         ...
# 1675  Based on the life of real-life Hero Major Sand...      19.029
# 1676  A young low-level drug dealer is reunited with...       0.600
# 1677  With his girlfriend pregnant, Dante, a pacifis...       3.136
# 1678  Nick, a talented photographer who is new to Lo...      18.247
# 1679  On the day before her wedding to a hipster pla...       1.134
#
#                            poster_path  \
# 0     /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1     /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2     /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 3     /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4     /nZGWnSuf1FIuzyEuMRZHHZWViAp.jpg
# ...                                ...
# 1675  /sJOfJuyQVZPwNQ8g21Qv0lojQhC.jpg
# 1676  /2HaAOGM1EmiSwsJrdq1RNhYehce.jpg
# 1677  /xppIANX9DQoRYg3FlNCifDYuFwP.jpg
# 1678  /df9pAqtYzM40llo9Joxy2ftqSrP.jpg
# 1679  /sioXCmW4Q2VXLYm9hIY8GcnU3m7.jpg
#
#                                    production_companies  \
# 0     [{'id': 60, 'logo_path': '/2eqFolQI0NLL7ExZts5...
# 1     [{'id': 925, 'logo_path': '/dIb9hjXNOkgxu4kBWd...
# 2                                                    []
# 3     [{'id': 539, 'logo_path': None, 'name': 'Block...
# 4     [{'id': 1596, 'logo_path': None, 'name': 'Shoo...
# ...                                                 ...
# 1675  [{'id': 69124, 'logo_path': None, 'name': 'G. ...
# 1676                                                 []
# 1677  [{'id': 109533, 'logo_path': '/xtQJYJg54jp5QVS...
# 1678  [{'id': 13238, 'logo_path': '/kDNZz8imH866Mezx...
# 1679                                                 []
#
#                                    production_countries release_date  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15
# 2               [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14
# 3           [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29
# 4     [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02
# ...                                                 ...          ...
# 1675            [{'iso_3166_1': 'IN', 'name': 'India'}]   2022-06-03
# 1676                                                 []   2022-05-13
# 1677  [{'iso_3166_1': 'US', 'name': 'United States o...   2022-03-13
# 1678  [{'iso_3166_1': 'US', 'name': 'United States o...   2022-08-12
# 1679                                                 []   2022-01-18
#
#        revenue  runtime                                   spoken_languages  \
# 0            0       86  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1            0      100  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2            0      152  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# 3     12854953       99  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 4            0       99  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...        ...      ...                                                ...
# 1675         0      149  [{'english_name': 'Telugu', 'iso_639_1': 'te',...
# 1676         0      101                                                 []
# 1677         0       96  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1678         0       89  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1679         0       82  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#         status                                            tagline  \
# 0     Released      Try to remember the first time magic happened
# 1     Released       The ultimate showdown on a forbidden planet.
# 2     Released                                                NaN
# 3     Released  Feel the heat, keep the feeling burning, let t...
# 4     Released  There's a fine line between friendship and bet...
# ...        ...                                                ...
# 1675  Released                              Jaan Doonga Desh Nahi
# 1676  Released                 Family Is The Last Line Of Defense
# 1677  Released  Warm nights... Feels like death in the sand du...
# 1678  Released            Find what you love and let it kill you.
# 1679  Released                  Everybody loves... somebody else.
#
#                      title  video  vote_average  vote_count certification
# 0          The Fantasticks  False         5.500          22           NaN
# 1            For the Cause  False         5.100           8           NaN
# 2                     Gang  False         0.000           0           NaN
# 3     In the Mood for Love  False         8.103        1948            PG
# 4           Chinese Coffee  False         6.900          46             R
# ...                    ...    ...           ...         ...           ...
# 1675                 Major  False         8.233          15           NaN
# 1676               Shadows  False         0.000           0           NaN
# 1677              Clowning  False         8.000           1           NaN
# 1678            No Way Out  False         3.000           3           NaN
# 1679          The Contrast  False         3.000           1           NaN
#
# [62007 rows x 26 columns]

# %%
df['revenue'] = df['revenue'].astype(float)

# %%
df = df.reset_index(drop=True)
df
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 0      False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 1      False                               NaN                   NaN
# 2      False                               NaN                   NaN
# 3      False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 4      False                               NaN                   NaN
# ...      ...                               ...                   ...
# 62002  False  /8tyq1kXM3YQmu3obW6LxWm5TVRO.jpg                   NaN
# 62003  False                               NaN                   NaN
# 62004  False                               NaN                   NaN
# 62005  False  /jX5XGqJUTzvpta2RjcX6pMZqxk5.jpg                   NaN
# 62006  False  /ibWj2ARVrAabIWDq5vSXoJRZfVV.jpg                   NaN
#
#          budget                                             genres  \
# 0      10000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1             0           [{'id': 878, 'name': 'Science Fiction'}]
# 2             0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3        150000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4             0                      [{'id': 18, 'name': 'Drama'}]
# ...         ...                                                ...
# 62002         0  [{'id': 28, 'name': 'Action'}, {'id': 36, 'nam...
# 62003         0                      [{'id': 80, 'name': 'Crime'}]
# 62004         0  [{'id': 80, 'name': 'Crime'}, {'id': 10749, 'n...
# 62005         0  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 62006         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                                    homepage      id    imdb_id  \
# 0                                       NaN   62127  tt0113026
# 1                                       NaN  110977  tt0113092
# 2                                       NaN  442869  tt0116391
# 3      http://www.wkw-inthemoodforlove.com/     843  tt0118694
# 4                                       NaN   49511  tt0118852
# ...                                     ...     ...        ...
# 62002                                   NaN  605153  tt9851854
# 62003                                   NaN  969840  tt9854058
# 62004                                   NaN  796955  tt9893158
# 62005                                   NaN  606303  tt9893160
# 62006            https://contrastmovie.com/  933557  tt9904648
#
#       original_language   original_title  \
# 0                    en  The Fantasticks
# 1                    en    For the Cause
# 2                    hi             Gang
# 3                    cn             花樣年華
# 4                    en   Chinese Coffee
# ...                 ...              ...
# 62002                te            మేజర్
# 62003                en          Shadows
# 62004                en         Clowning
# 62005                en       No Way Out
# 62006                en     The Contrast
#
#                                                 overview  popularity  \
# 0      Two rural teens sing and dance their way throu...       2.289
# 1      Earth is in a state of constant war and two co...       3.133
# 2      After falling prey to underworld, four friends...       1.091
# 3      Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...      22.892
# 4      When Harry Levine, an aging, unsuccessful Gree...       3.913
# ...                                                  ...         ...
# 62002  Based on the life of real-life Hero Major Sand...      19.029
# 62003  A young low-level drug dealer is reunited with...       0.600
# 62004  With his girlfriend pregnant, Dante, a pacifis...       3.136
# 62005  Nick, a talented photographer who is new to Lo...      18.247
# 62006  On the day before her wedding to a hipster pla...       1.134
#
#                             poster_path  \
# 0      /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1      /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2      /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 3      /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4      /nZGWnSuf1FIuzyEuMRZHHZWViAp.jpg
# ...                                 ...
# 62002  /sJOfJuyQVZPwNQ8g21Qv0lojQhC.jpg
# 62003  /2HaAOGM1EmiSwsJrdq1RNhYehce.jpg
# 62004  /xppIANX9DQoRYg3FlNCifDYuFwP.jpg
# 62005  /df9pAqtYzM40llo9Joxy2ftqSrP.jpg
# 62006  /sioXCmW4Q2VXLYm9hIY8GcnU3m7.jpg
#
#                                     production_companies  \
# 0      [{'id': 60, 'logo_path': '/2eqFolQI0NLL7ExZts5...
# 1      [{'id': 925, 'logo_path': '/dIb9hjXNOkgxu4kBWd...
# 2                                                     []
# 3      [{'id': 539, 'logo_path': None, 'name': 'Block...
# 4      [{'id': 1596, 'logo_path': None, 'name': 'Shoo...
# ...                                                  ...
# 62002  [{'id': 69124, 'logo_path': None, 'name': 'G. ...
# 62003                                                 []
# 62004  [{'id': 109533, 'logo_path': '/xtQJYJg54jp5QVS...
# 62005  [{'id': 13238, 'logo_path': '/kDNZz8imH866Mezx...
# 62006                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15
# 2                [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14
# 3            [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02
# ...                                                  ...          ...
# 62002            [{'iso_3166_1': 'IN', 'name': 'India'}]   2022-06-03
# 62003                                                 []   2022-05-13
# 62004  [{'iso_3166_1': 'US', 'name': 'United States o...   2022-03-13
# 62005  [{'iso_3166_1': 'US', 'name': 'United States o...   2022-08-12
# 62006                                                 []   2022-01-18
#
#           revenue  runtime                                   spoken_languages  \
# 0             0.0       86  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1             0.0      100  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2             0.0      152  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# 3      12854953.0       99  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 4             0.0       99  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...           ...      ...                                                ...
# 62002         0.0      149  [{'english_name': 'Telugu', 'iso_639_1': 'te',...
# 62003         0.0      101                                                 []
# 62004         0.0       96  [{'english_name': 'English', 'iso_639_1': 'en'...
# 62005         0.0       89  [{'english_name': 'English', 'iso_639_1': 'en'...
# 62006         0.0       82  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#          status                                            tagline  \
# 0      Released      Try to remember the first time magic happened
# 1      Released       The ultimate showdown on a forbidden planet.
# 2      Released                                                NaN
# 3      Released  Feel the heat, keep the feeling burning, let t...
# 4      Released  There's a fine line between friendship and bet...
# ...         ...                                                ...
# 62002  Released                              Jaan Doonga Desh Nahi
# 62003  Released                 Family Is The Last Line Of Defense
# 62004  Released  Warm nights... Feels like death in the sand du...
# 62005  Released            Find what you love and let it kill you.
# 62006  Released                  Everybody loves... somebody else.
#
#                       title  video  vote_average  vote_count certification
# 0           The Fantasticks  False         5.500          22           NaN
# 1             For the Cause  False         5.100           8           NaN
# 2                      Gang  False         0.000           0           NaN
# 3      In the Mood for Love  False         8.103        1948            PG
# 4            Chinese Coffee  False         6.900          46             R
# ...                     ...    ...           ...         ...           ...
# 62002                 Major  False         8.233          15           NaN
# 62003               Shadows  False         0.000           0           NaN
# 62004              Clowning  False         8.000           1           NaN
# 62005            No Way Out  False         3.000           3           NaN
# 62006          The Contrast  False         3.000           1           NaN
#
# [62007 rows x 26 columns]

# %%
schema = get_schema(df)
schema['title'] = Text()
schema['original_title'] = Text()

# %%
schema
# Out:
# {'adult': Boolean(),
#  'backdrop_path': String(length=33),
#  'belongs_to_collection': String(length=198),
#  'genres': String(length=257),
#  'homepage': String(length=211),
#  'imdb_id': String(length=11),
#  'original_language': String(length=3),
#  'original_title': Text(),
#  'overview': String(length=1001),
#  'popularity': Float(),
#  'poster_path': String(length=33),
#  'production_companies': String(length=2944),
#  'production_countries': String(length=1061),
#  'release_date': String(length=11),
#  'revenue': Float(),
#  'spoken_languages': String(length=943),
#  'status': String(length=16),
#  'tagline': String(length=257),
#  'title': Text(),
#  'video': Boolean(),
#  'vote_average': Float(),
#  'certification': String(length=32)}

# %%
df_for_db = df.drop(columns=['title','original_title'])
df_for_db
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 0      False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 1      False                               NaN                   NaN
# 2      False                               NaN                   NaN
# 3      False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 4      False                               NaN                   NaN
# ...      ...                               ...                   ...
# 62002  False  /8tyq1kXM3YQmu3obW6LxWm5TVRO.jpg                   NaN
# 62003  False                               NaN                   NaN
# 62004  False                               NaN                   NaN
# 62005  False  /jX5XGqJUTzvpta2RjcX6pMZqxk5.jpg                   NaN
# 62006  False  /ibWj2ARVrAabIWDq5vSXoJRZfVV.jpg                   NaN
#
#          budget                                             genres  \
# 0      10000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1             0           [{'id': 878, 'name': 'Science Fiction'}]
# 2             0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3        150000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4             0                      [{'id': 18, 'name': 'Drama'}]
# ...         ...                                                ...
# 62002         0  [{'id': 28, 'name': 'Action'}, {'id': 36, 'nam...
# 62003         0                      [{'id': 80, 'name': 'Crime'}]
# 62004         0  [{'id': 80, 'name': 'Crime'}, {'id': 10749, 'n...
# 62005         0  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 62006         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                                    homepage      id    imdb_id  \
# 0                                       NaN   62127  tt0113026
# 1                                       NaN  110977  tt0113092
# 2                                       NaN  442869  tt0116391
# 3      http://www.wkw-inthemoodforlove.com/     843  tt0118694
# 4                                       NaN   49511  tt0118852
# ...                                     ...     ...        ...
# 62002                                   NaN  605153  tt9851854
# 62003                                   NaN  969840  tt9854058
# 62004                                   NaN  796955  tt9893158
# 62005                                   NaN  606303  tt9893160
# 62006            https://contrastmovie.com/  933557  tt9904648
#
#       original_language                                           overview  \
# 0                    en  Two rural teens sing and dance their way throu...
# 1                    en  Earth is in a state of constant war and two co...
# 2                    hi  After falling prey to underworld, four friends...
# 3                    cn  Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...
# 4                    en  When Harry Levine, an aging, unsuccessful Gree...
# ...                 ...                                                ...
# 62002                te  Based on the life of real-life Hero Major Sand...
# 62003                en  A young low-level drug dealer is reunited with...
# 62004                en  With his girlfriend pregnant, Dante, a pacifis...
# 62005                en  Nick, a talented photographer who is new to Lo...
# 62006                en  On the day before her wedding to a hipster pla...
#
#        popularity                       poster_path  \
# 0           2.289  /hfO64mXz3DgUxkBVU7no2UWRP7x.jpg
# 1           3.133  /h9bWO13nWRGZJo4XVPiElXyrRMU.jpg
# 2           1.091  /yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg
# 3          22.892  /iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg
# 4           3.913  /nZGWnSuf1FIuzyEuMRZHHZWViAp.jpg
# ...           ...                               ...
# 62002      19.029  /sJOfJuyQVZPwNQ8g21Qv0lojQhC.jpg
# 62003       0.600  /2HaAOGM1EmiSwsJrdq1RNhYehce.jpg
# 62004       3.136  /xppIANX9DQoRYg3FlNCifDYuFwP.jpg
# 62005      18.247  /df9pAqtYzM40llo9Joxy2ftqSrP.jpg
# 62006       1.134  /sioXCmW4Q2VXLYm9hIY8GcnU3m7.jpg
#
#                                     production_companies  \
# 0      [{'id': 60, 'logo_path': '/2eqFolQI0NLL7ExZts5...
# 1      [{'id': 925, 'logo_path': '/dIb9hjXNOkgxu4kBWd...
# 2                                                     []
# 3      [{'id': 539, 'logo_path': None, 'name': 'Block...
# 4      [{'id': 1596, 'logo_path': None, 'name': 'Shoo...
# ...                                                  ...
# 62002  [{'id': 69124, 'logo_path': None, 'name': 'G. ...
# 62003                                                 []
# 62004  [{'id': 109533, 'logo_path': '/xtQJYJg54jp5QVS...
# 62005  [{'id': 13238, 'logo_path': '/kDNZz8imH866Mezx...
# 62006                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-22
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-11-15
# 2                [{'iso_3166_1': 'IN', 'name': 'India'}]   2000-04-14
# 3            [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]   2000-09-29
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   2000-09-02
# ...                                                  ...          ...
# 62002            [{'iso_3166_1': 'IN', 'name': 'India'}]   2022-06-03
# 62003                                                 []   2022-05-13
# 62004  [{'iso_3166_1': 'US', 'name': 'United States o...   2022-03-13
# 62005  [{'iso_3166_1': 'US', 'name': 'United States o...   2022-08-12
# 62006                                                 []   2022-01-18
#
#           revenue  runtime                                   spoken_languages  \
# 0             0.0       86  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1             0.0      100  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2             0.0      152  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# 3      12854953.0       99  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 4             0.0       99  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...           ...      ...                                                ...
# 62002         0.0      149  [{'english_name': 'Telugu', 'iso_639_1': 'te',...
# 62003         0.0      101                                                 []
# 62004         0.0       96  [{'english_name': 'English', 'iso_639_1': 'en'...
# 62005         0.0       89  [{'english_name': 'English', 'iso_639_1': 'en'...
# 62006         0.0       82  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#          status                                            tagline  video  \
# 0      Released      Try to remember the first time magic happened  False
# 1      Released       The ultimate showdown on a forbidden planet.  False
# 2      Released                                                NaN  False
# 3      Released  Feel the heat, keep the feeling burning, let t...  False
# 4      Released  There's a fine line between friendship and bet...  False
# ...         ...                                                ...    ...
# 62002  Released                              Jaan Doonga Desh Nahi  False
# 62003  Released                 Family Is The Last Line Of Defense  False
# 62004  Released  Warm nights... Feels like death in the sand du...  False
# 62005  Released            Find what you love and let it kill you.  False
# 62006  Released                  Everybody loves... somebody else.  False
#
#        vote_average  vote_count certification
# 0             5.500          22           NaN
# 1             5.100           8           NaN
# 2             0.000           0           NaN
# 3             8.103        1948            PG
# 4             6.900          46             R
# ...             ...         ...           ...
# 62002         8.233          15           NaN
# 62003         0.000           0           NaN
# 62004         8.000           1           NaN
# 62005         3.000           3           NaN
# 62006         3.000           1           NaN
#
# [62007 rows x 24 columns]

# %%
df_for_db.to_sql('tmdb_data_aab',engine, index=False, 
                            if_exists='replace',dtype=get_schema(df_for_db))
#                           method='multi')
# Out:
# 62007

# %%
# ## loop through adding more columns and remove what errors
# good_cols = [*cols_to_keep]
# bad_cols = []
# all_cols = df.drop(columns=cols_to_keep).columns

# for col in all_cols:
#     print(f"- Adding {col}")
#     try: 
#         cols_to_try = [*good_cols, col]
#         df_filtered = df[ cols_to_try]
#         schema= get_schema(df_filtered)
#         ## Primary key is Genre_ID
#         df_filtered.to_sql('tmdb_data_aab',engine, index=False,
#                             if_exists='replace',#dtype=schema,
#                           method='multi')
        
#         # append col name to good_cols if no error
#         good_cols.append(col)
#     except Exception as e:
#         print("   - ERROR")
#         bad_cols.append({col:e})
# bad_cols

# %%
engine.execute('ALTER TABLE tmdb_data_aab ADD PRIMARY KEY (`imdb_id`);')

# %%
q = """SELECT * FROM tmdb_data_aab LIMIT 5"""
pd.read_sql(q,engine)
# Out:
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0      0  /ab5yL8zgRotrICzGbEl10z24N71.jpg                  None  48000000
# 1      0  /fw5tsNib4QZBEw18xmebpVe3WZ8.jpg                  None         0
# 2      0  /zjG95oDnBcFKMPgBEmmuNVOMC90.jpg                  None  12000000
# 3      0                              None                  None    350000
# 4      0                              None                  None       187
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 4  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                     homepage      id    imdb_id  \
# 0                                       None   11232  tt0035423
# 1  http://poetastros.com/el-tango-del-viudo/  602986  tt0062336
# 2     https://www.netflix.com/title/80085566  299782  tt0069049
# 3                                       None   29163  tt0088751
# 4                                       None  431608  tt0094859
#
#   original_language                                           overview  \
# 0                en  When her scientist ex-boyfriend discovers a po...
# 1                es  A man whose wife has committed suicide,  appea...
# 2                en  Surrounded by fans and skeptics, grizzled dire...
# 3                en  Using soundtracks and extensive footage from m...
# 4                en  An outrageous social comedy about a New York r...
#
#    popularity                       poster_path  \
# 0      15.993  /mUvikzKJJSg9khrVdxK8kg3TMHA.jpg
# 1       1.231  /yzbqP9woGq2wGUJh0DzVXlr3Th7.jpg
# 2       8.220  /kFky1paYEfHxfCYByEc9g7gn6Zk.jpg
# 3       1.672  /aYbeNeNID1wLBp9l214w8CU00xd.jpg
# 4       0.848                              None
#
#                                 production_companies  \
# 0  [{'id': 14, 'logo_path': '/m6AHu84oZQxvq7n1rsv...
# 1  [{'id': 96241, 'logo_path': None, 'name': 'Poe...
# 2  [{'id': 7573, 'logo_path': None, 'name': "Les ...
# 3                                                 []
# 4                                                 []
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2001-12-25  76019000.0
# 1            [{'iso_3166_1': 'CL', 'name': 'Chile'}]   2020-02-21         0.0
# 2  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   2018-11-02         0.0
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   2005-04-22         0.0
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2016-10-28         0.0
#
#    runtime                                   spoken_languages    status  \
# 0      118  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1       63  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
# 2      122  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3      100  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4       74                                                 []  Released
#
#                                              tagline  video  vote_average  \
# 0  If they lived in the same century they'd be pe...      0         6.317
# 1                                               None      0         5.300
# 2                             40 years in the making      0         6.694
# 3                                               None      0         3.400
# 4  An outrageous social comedy about a New York r...      0         0.000
#
#    vote_count certification
# 0        1137         PG-13
# 1           3          None
# 2         157             R
# 3           5          None
# 4           0          None

# %% [markdown]
# # Final Tables Check

# %%
## Test your connection by checking for any tables that exist (there should be none at this point)
q = """SHOW TABLES;"""
pd.read_sql(q, engine)
# Out:
#   Tables_in_movies
# 0           genres
# 1     title_basics
# 2     title_genres
# 3    title_ratings
# 4    tmdb_data_aab
# 5    tmdb_data_mvp
